# %% [markdown]
# token --> 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

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/resnet50-for-cifar10"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

from getpass import getpass

token = getpass('Enter your GitHub token: ')

# !git remote remove origin || true  # ignore error if origin doesn't exist
repo_url = f"https://{token}@github.com/Benguerine/resnet50-for-cifar10.git"
# !git remote add origin {repo_url}

# !git add .
# !git commit -m "Initial commit from Colab"

# !git pull origin main --rebase
# !git push origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/resnet50-for-cifar10/.git/
# Enter your GitHub token: ··········
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `git remote add origin https://Reinitialized existing Git repository in /content/drive/MyDrive/resnet50-for-cifar10/.git/ Enter your GitHub token: ·········· [master 4ec80a3] Initial commit from Colab  1 file changed, 1 insertion(+), 1 deletion(-)  rewrite Copy of Git.ipynb (89%) remote: Write access to repository not granted. fatal: unable to access 'https://github.com/Benguerine/resnet50-for-cifar10.git/': The requested URL returned error: 403 error: src refspec main does not match any error: failed to push some refs to 'https://github.com/Benguerine/resnet50-for-cifar10.git'@github.com/Benguerine/resnet50-for-cifar10.git'
# [master 8ed6d3a] Initial commit from Colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# error: src refspec main does not match any
# error: failed to push some refs to 'origin'
