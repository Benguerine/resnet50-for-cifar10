# %% [markdown]
# token --> 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

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/resnet50-for-cifar10"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

from getpass import getpass

token = getpass('Enter your GitHub token: ')

# !git remote remove origin || true  # ignore error if origin doesn't exist
repo_url = f"https://{token}@github.com/Benguerine/resnet50-for-cifar10.git"
# !git remote add origin {repo_url}

# !git add .
# !git commit -m "Initial commit from Colab"

# !git pull origin main --rebase
# !git push origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Dive into deep learning with tensorflow/.git/
# Enter your GitHub token: ··········
# [main c5df90b] Initial commit from Colab
#  2 files changed, 2 insertions(+), 2 deletions(-)
# From https://github.com/Benguerine/DeepLearningJourney
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Current branch main is up to date.
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.36 KiB | 138.00 KiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Benguerine/DeepLearningJourney.git
#    cecb257..c5df90b  main -> main
