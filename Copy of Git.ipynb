# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from getpass import getpass

# Step 1: Set working directory
folder_path = "/content/drive/MyDrive/resnet50-for-cifar10"
os.chdir(folder_path)

# Step 2: Initialize Git and configure identity
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

# Step 3: Rename branch
# !git branch -M main

# Step 4: Get GitHub token securely
##token = getpass("Enter your GitHub token: ")

# Step 5: Add remote origin (remove if exists)
# !git remote remove origin 2> /dev/null
repo_url = f"https://{cifar-hugg-fast-ml}@github.com/Benguerine/resnet50-for-cifar10.git"
# !git remote add origin $repo_url

# Step 6: Stage & commit local changes
# !git add .
# !git commit -m "Commit from Colab" || echo "Nothing new to commit"

# Step 7: Pull remote changes (merge with GitHub repo)
# !git pull origin main --rebase

# Step 8: Push merged repo back to GitHub
# !git push origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/resnet50-for-cifar10/.git/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2737307501.py in <cell line: 0>()
#      19 # Step 5: Add remote origin (remove if exists)
#      20 get_ipython().system('git remote remove origin 2> /dev/null')
# ---> 21 repo_url = f"https://{cifar-hugg-fast-ml}@github.com/Benguerine/resnet50-for-cifar10.git"
#      22 get_ipython().system('git remote add origin $repo_url')
#      23
#
# NameError: name 'cifar' is not defined
