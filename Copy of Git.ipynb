# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from getpass import getpass

# Your repo info
username = "Benguerine"
repo = "resnet50-for-cifar10"

# Ask for token
token = getpass("Enter your GitHub token: ")

# Build remote URL properly
repo_url = f"https://{username}:{token}@github.com/{username}/{repo}.git"

# Reset remote
os.system("git remote remove origin")
os.system(f"git remote add origin {repo_url}")

# Push
# !git add .
# !git commit -m "Initial commit from Colab"
# !git push -u origin main
# Out:
# Enter your GitHub token: ··········
# On branch main
# nothing to commit, working tree clean
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/Benguerine/resnet50-for-cifar10.git/'
