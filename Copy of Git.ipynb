# %% [markdown]
# token --> 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

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from getpass import getpass

# Step 1: Set working directory to your repo folder
folder_path = "/content/drive/MyDrive/resnet50-for-cifar10"
os.chdir(folder_path)

# Step 2: Initialize Git and configure your identity
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

# Step 3: Rename current branch to 'main'
# !git branch -M main

# Step 4: Ask user for GitHub token securely
token = getpass("Enter your GitHub token: ")

# Step 5: Set remote origin (replace existing if needed)
# !git remote remove origin 2> /dev/null
repo_url = f"https://{token}@github.com/Benguerine/resnet50-for-cifar10.git"
# !git remote add origin "{repo_url}"

# Step 6: Stage and commit all files
# !git add .
# !git commit -m "Initial commit from Colab"

# Step 7: Push to GitHub
# !git push -u origin main
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2-2793462851.py in <cell line: 0>()
#       4 # Step 1: Set working directory to your repo folder
#       5 folder_path = "/content/drive/MyDrive/resnet50-for-cifar10"
# ----> 6 os.chdir(folder_path)
#       7
#       8 # Step 2: Initialize Git and configure your identity
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/resnet50-for-cifar10'
