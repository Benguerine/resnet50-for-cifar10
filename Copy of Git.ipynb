# %% [markdown]
# token --> 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

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from getpass import getpass

# Set working directory
folder_path = "/content/drive/MyDrive/resnet50-for-cifar10"
os.chdir(folder_path)

# Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"
# !git branch -M main  # Rename default branch to 'main'

# Get token securely
token = getpass("Enter your GitHub token: ")

# Set correct remote
# !git remote remove origin 2> /dev/null  # Remove old if exists
repo_url = f"https://{token}@github.com/Benguerine/resnet50-for-cifar10.git"
# !git remote add origin "{repo_url}"

# Commit and push
# !git add .
# !git commit -m "Initial commit from Colab"
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/resnet50-for-cifar10/.git/
# Enter your GitHub token: ··········
# [main ffc7ede] Initial commit from Colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Copy of Git.ipynb (86%)
# remote: Write access to repository not granted.
# fatal: unable to access 'https://github.com/Benguerine/resnet50-for-cifar10.git/': The requested URL returned error: 403
