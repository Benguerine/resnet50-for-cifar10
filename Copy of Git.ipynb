# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from getpass import getpass

# Step 1: Set working directory
folder_path = "/content/drive/MyDrive/resnet50-for-cifar10"
os.chdir(folder_path)

# Step 2: Initialize Git and configure identity
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

# Step 3: Rename branch
# !git branch -M main

# Step 4: Ask for token
token = getpass("Enter your GitHub token: ")

# Step 5: Set remote origin (using Python variables correctly)
repo_url = f"https://{token}@github.com/Benguerine/resnet50-for-cifar10.git"
os.system("git remote remove origin")  # ignore if none
os.system(f"git remote add origin {repo_url}")

# Step 6: Stage and commit
# !git add .
# !git commit -m "Initial commit from Colab"

# Step 7: Push
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/resnet50-for-cifar10/.git/
# Enter your GitHub token: ··········
# [main 842d7c0] Initial commit from Colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: could not read Password for 'https://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@github.com': No such device or address
